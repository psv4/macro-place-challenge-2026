# %%
from macro_place.loader import load_benchmark_from_dir
from macro_place.objective import compute_proxy_cost
from macro_place.utils import validate_placement

# %%
benchmark, plc = load_benchmark_from_dir("external/MacroPlacement/Testcases/ICCAD04/ibm01")
# Out:
# #[INFO] Reading from external/MacroPlacement/Testcases/ICCAD04/ibm01\netlist.pb.txt
# [INFO] Retrieving Meta information from .plc comments
# #[PLACEMENT GRID] Col: 45, Row: 41
# #[ROUTES PER MICRON] Hor: 65.96, Ver: 106.96
# #[CONGESTION SMOOTH RANGE] Smooth Range: 2
# #[OVERLAP THRESHOLD] Threshold: 0.0040

# %%
benchmark
# Out:
# Benchmark(name='ibm01', hard_macros=246, soft_macros=894, num_nets=5993, canvas=22.9x23.0um)

# %%
len(benchmark.port_positions)
# Out:
# 246

# %%
for (hmi, mpo) in zip(benchmark.hard_macro_indices, benchmark.macro_pin_offsets):
    print(hmi, mpo)
# Out:
# 246 tensor([[ 0.4200,  0.4154],
#         [ 0.2077, -0.4800],
#         [ 0.4200, -0.4154],
#         [ 0.4200, -0.1385],
#         [ 0.4200,  0.1385],
#         [-0.4200, -0.4800],
#         [-0.3462, -0.4800],
#         [-0.0692, -0.4800],
#         [ 0.2077,  0.4800],
#         [-0.0692,  0.4800],
#         [-0.3462,  0.4800],
#         [-0.4200,  0.2769],
#         [-0.4200, -0.2031]])
# 260 tensor([[-0.0692, -0.4800],
#         [ 0.2077, -0.4800],
#         [ 0.4200, -0.4154],
#         [ 0.4200, -0.1385],
#         [-0.4200,  0.2769],
#         [-0.4200, -0.2031],
#         [ 0.4200,  0.1385],
#         [-0.3462, -0.4800],
#         [ 0.4200,  0.4154],
#         [-0.4200, -0.4800],
#         [ 0.2077,  0.4800],
#         [-0.0692,  0.4800],
#         [-0.3462,  0.4800]])
# 274 tensor([[-0.0696, -0.4000],
#         [ 0.2088, -0.4000],
#         [ 0.4873, -0.4000],
#         [ 0.5050, -0.1392],
#         [ 0.5050,  0.1392],
#         [-0.5050, -0.1215],
# ...

# %%
print(len(benchmark.net_nodes))
benchmark.net_nodes
# Out:
# 5993
# [tensor([ 140, 1142]),
#  tensor([  57, 1145]),
#  tensor([ 144, 1146]),
#  tensor([ 187, 1149]),
#  tensor([ 212, 1150]),
#  tensor([ 108, 1152]),
#  tensor([ 114, 1153]),
#  tensor([   0, 1155]),
#  tensor([ 208, 1158]),
#  tensor([  75, 1160]),
#  tensor([   9, 1161]),
#  tensor([ 185, 1162]),
#  tensor([  94, 1165]),
#  tensor([  80, 1166]),
#  tensor([ 173, 1168]),
#  tensor([   7, 1169]),
#  tensor([ 184, 1171]),
#  tensor([  83, 1172]),
#  tensor([ 148, 1175]),
#  tensor([  36, 1176]),
#  tensor([  52, 1184]),
#  tensor([  81, 1187]),
#  tensor([  90, 1195]),
#  tensor([ 198, 1196]),
#  tensor([  53, 1198]),
#  tensor([ 197, 1202]),
#  tensor([ 196, 1203]),
#  tensor([ 176, 1204]),
#  tensor([   6, 1205]),
#  tensor([ 166, 1207]),
#  tensor([  32, 1208]),
#  tensor([ 128, 1209]),
#  tensor([  26, 1210]),
#  tensor([ 157, 1211]),
#  tensor([ 133, 1212]),
#  tensor([  24, 1214]),
#  tensor([ 107, 1215]),
#  tensor([ 167, 1216]),
#  tensor([  47, 1219]),
# ...
